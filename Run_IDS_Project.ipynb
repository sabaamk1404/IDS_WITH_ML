# %% [markdown]
# <a href="https://colab.research.google.com/github/sabaamk1404/IDS_WITH_ML/blob/main/Run_IDS_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intrusion Detection System (IDS)
#
# This notebook automatically runs the Streamlit application (`app.py`)
#
# ▶️ **Run all cells to get a access link**

# %%
# !git clone https://github.com/sabaamk1404/IDS_WITH_ML.git
# %cd IDS_WITH_ML
# Out:
# Cloning into 'IDS_WITH_ML'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 111 (delta 42), reused 55 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 14.65 MiB | 16.01 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/IDS_WITH_ML

# %%
# !pip install -q streamlit numpy pandas scikit-learn joblib

# %%
# !pkill -f streamlit || true

# !streamlit run app.py \
  --server.port 8501 \
  --server.address 0.0.0.0 \
  --server.headless true \
  &> /content/streamlit.log &
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   URL: http://0.0.0.0:8501
#
#   Stopping...
# Traceback (most recent call last):
#   File "/usr/local/bin/streamlit", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1485, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1406, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1873, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 1269, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/core.py", line 824, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/cli.py", line 251, in main_run
#     _main_run(path_str, args, flag_options=kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/cli.py", line 308, in _main_run
#     bootstrap.run(file, is_hello, args, flag_options)
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 356, in run
#     asyncio.run(main())
#   File "/usr/lib/python3.12/asyncio/runners.py", line 195, in run
#     return runner.run(main)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/runners.py", line 118, in run
#     return self._loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 678, in run_until_complete
#     self.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1961, in _run_once
#     event_list = self._selector.select(timeout)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/selectors.py", line 468, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 42, in signal_handler
#     server.stop()
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/server/server.py", line 518, in stop
#     cli_util.print_to_cli("  Stopping...", fg="blue")
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/cli_util.py", line 35, in print_to_cli
#     click.secho(message, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/click/termui.py", line 690, in secho
#     return echo(message, file=file, nl=nl, err=err, color=color)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/utils.py", line 321, in echo
#     file.write(out)  # type: ignore
#     ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/bootstrap.py", line 42, in signal_handler
#     server.stop()
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/web/server/server.py", line 518, in stop
#     cli_util.print_to_cli("  Stopping...", fg="blue")
#   File "/usr/local/lib/python3.12/dist-packages/streamlit/cli_util.py", line 35, in print_to_cli
#     click.secho(message, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/click/termui.py", line 690, in secho
#     return echo(message, file=file, nl=nl, err=err, color=color)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/click/utils.py", line 321, in echo
#     file.write(out)  # type: ignore
#     ^^^^^^^^^^^^^^^
# RuntimeError: reentrant call inside <_io.BufferedWriter name='<stdout>'>

# %%
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !./cloudflared tunnel --url http://127.0.0.1:8501
# Out:
# 2026-01-02T12:00:12Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-01-02T12:00:12Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-01-02T12:00:17Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-02T12:00:17Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-01-02T12:00:17Z INF |  https://cannon-authentication-yorkshire-communications.trycloudflare.com                  |
# 2026-01-02T12:00:17Z INF +--------------------------------------------------------------------------------------------+
# 2026-01-02T12:00:17Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-01-02T12:00:17Z INF Version 2025.11.1 (Checksum 991dffd8889ee9f0147b6b48933da9e4407e68ea8c6d984f55fa2d3db4bb431d)
# 2026-01-02T12:00:17Z INF GOOS: linux, GOVersion: go1.24.9, GoArch: amd64
# 2026-01-02T12:00:17Z INF Settings: map[ha-connections:1 protocol:quic url:http://127.0.0.1:8501]
# 2026-01-02T12:00:17Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-01-02T12:00:17Z INF Generated Connector ID: 150221f4-ec65-4463-aa97-4176bf6d1ca7
# 2026-01-02T12:00:17Z INF Initial protocol quic
# 2026-01-02T12:00:17Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-01-02T12:00:17Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-01-02T12:00:17Z ERR Cannot determine default origin certificate path. No file cert.pem in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]. You need to specify the origin certificate path by specifying the origincert option in the configuration file, or set TUNNEL_ORIGIN_CERT environment variable originCertPath=
# 2026-01-02T12:00:17Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-01-02T12:00:17Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-01-02T12:00:17Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-01-02T12:00:17Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026/01/02 12:00:17 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-01-02T12:00:17Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:17Z ERR failed to serve tunnel connection error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:17Z ERR Serve tunnel error error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:17Z INF Retrying connection in up to 2s connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:18Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:19Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:19Z ERR failed to serve tunnel connection error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:19Z ERR Serve tunnel error error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:19Z INF Retrying connection in up to 4s connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:22Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:22Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:22Z ERR failed to serve tunnel connection error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:22Z ERR Serve tunnel error error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:22Z INF Retrying connection in up to 8s connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:26Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:26Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:26Z ERR failed to serve tunnel connection error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:26Z ERR Serve tunnel error error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:26Z INF Retrying connection in up to 16s connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:41Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.27
# 2026-01-02T12:00:42Z INF Registered tunnel connection connIndex=0 connection=f1a01de4-cf9d-4d14-8bd6-70b80204c0a6 event=0 ip=198.41.192.27 location=ord06 protocol=quic
